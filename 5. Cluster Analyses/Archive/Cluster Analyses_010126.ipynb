# %%
Output = ('/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1013. Microbiome Peanut Allergy/P1013.3. Analyses/P1013.4. Outcome Prediction/Output')
cur_date = "010326"

library(readxl)
library(tidyverse)
library(Hmisc)
library(ggsci)
library(ggrepel)
library(umap)
library(gtsummary)
library(ggpubr)
library(cowplot)

# reading in files
saliva_df = data.frame(read_excel("Input/Processed_Saliva_Data_090525.xlsx")) %>%
    mutate(Age = as.numeric(Age), IgE = as.numeric(IgE))
stool_df = data.frame(read_excel("Input/Processed_Stool_Data_090525.xlsx")) %>%
    mutate(Age = as.numeric(Age), IgE = as.numeric(IgE))
saliva_paired_outcome_df = data.frame(read_excel("Input/Saliva_Adj_Paired_Outcome_112025.xlsx")) %>%
    filter(P.Adj < 0.1)
stool_paired_outcome_df = data.frame(read_excel("Input/Stool_Adj_Paired_Outcome_112025.xlsx")) %>%
    filter(P.Adj < 0.1)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     src, summarize
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
#
#
#
# Attaching package: ‘cowplot’
#
#
# The following object is masked from ‘package:ggpubr’:
#
#     get_legend
#
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp

# %%
combined_saliva_df = saliva_df %>%
    # normalizing
    mutate(across(c(10:ncol(saliva_df)), ~ log(.x + 2))) %>%
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    filter(IgE_Binarized != 'Fail') %>%
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))
combined_stool_df = stool_df %>%
    mutate(across(c(11:ncol(stool_df)), ~ log(.x + 2))) %>%
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    filter(IgE_Binarized != 'Fail') %>%
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

# %% [markdown]
# # Comparing Baseline Bacteria Abundances

# %%
v1_saliva_df = combined_saliva_df %>%
    # only keep participants' baseline samples and those given active treatment
    filter(Time_Point == 'Pre' & Treatment == 'A') 

v1_stool_df = combined_stool_df %>%
    filter(Time_Point == 'Pre' & Treatment == 'A') 

head(v1_saliva_df)
# Out:
#   Original_Sample_ID Subject_No Sample_ID Time_Point Treatment
# 1 FS02baseline        2         Pre_2     Pre        A
# 2 FS05baseline        4         Pre_4     Pre        A
# 3 FS07baseline        6         Pre_6     Pre        A
# 4 FS10baseline        9         Pre_9     Pre        A
# 5 FS12baseline       11         Pre_11    Pre        A
# 6 FS15baseline       14         Pre_14    Pre        A
#   Outcome                    Age      IgE    IgE_Binarized
# 1 Failure                    1.873973  14.20 Low
# 2 Failure                    3.991781   9.59 Low
# 3 Sustained Unresponsiveness 1.419178   1.32 Low
# 4 Sustained Unresponsiveness 1.389041   0.42 Low
# 5 Failure                    1.567123   4.34 Low
# 6 Failure                    3.912329 105.00 High
#   k__Bacteria.__.__.__.__.__.__ ⋯
# 1 0.6931472                     ⋯
# 2 3.2580965                     ⋯
# 3 2.1972246                     ⋯
# 4 2.3978953                     ⋯
# 5 2.3025851                     ⋯
# 6 1.3862944                     ⋯
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# 1 0.6931472
# 2 0.6931472
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 2.3025851
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# 1 0.6931472
# 2 0.6931472
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.s__aphrophilus
# 1 3.8712010
# 2 0.6931472
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.__
# 1 5.921578
# 2 4.718499
# 3 7.748029
# 4 7.280697
# 5 2.890372
# 6 3.555348
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.s__parainfluenzae
# 1 8.119994
# 2 7.112327
# 3 7.590852
# 4 8.360773
# 5 8.445482
# 6 5.575949
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# 1 0.6931472
# 2 3.7376696
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_347
# 1 0.6931472
# 2 1.7917595
# 3 2.8903718
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_352
# 1 0.6931472
# 2 6.0038871
# 3 0.6931472
# 4 0.6931472
# 5 3.6635616
# 6 7.2909748
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.3..s__bacterium_HMT_351
# 1 0.6931472
# 2 3.6109179
# 3 1.9459101
# 4 0.6931472
# 5 2.1972246
# 6 4.0943446
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.6..s__bacterium_HMT_870
# 1 4.736198
# 2 5.129899
# 3 3.401197
# 4 2.197225
# 5 3.496508
# 6 4.060443

# %%
# setting seed for reproducibility and running umap
saliva_umap_outcome = umap(v1_saliva_df[,c(10:ncol(v1_saliva_df))], random_state = 12)
stool_umap_outcome = umap(v1_stool_df[,c(11:ncol(v1_stool_df))], random_state = 12)

saliva_umap_outcome_df = data.frame(X = saliva_umap_outcome$layout[,1],
                     Y = saliva_umap_outcome$layout[,2],
                     Sample_ID = v1_saliva_df$Sample_ID,
                     Outcome = v1_saliva_df$Outcome,
                     Age = v1_saliva_df$Age,
                     IgE = v1_saliva_df$IgE_Binarized) %>%
    mutate(IgE = factor(IgE, levels = c('Low', 'High'))) 

stool_umap_outcome_df = data.frame(X = stool_umap_outcome$layout[,1],
                     Y = stool_umap_outcome$layout[,2],
                     Sample_ID = v1_stool_df$Sample_ID,
                     Outcome = v1_stool_df$Outcome,
                     Age = v1_stool_df$Age,
                     IgE = v1_stool_df$IgE_Binarized) %>%
    mutate(IgE = factor(IgE, levels = c('Low', 'High'))) 

head(saliva_umap_outcome_df)
# Out:
#   X          Y          Sample_ID Outcome                    Age      IgE
# 1 -0.4581162 -0.1800874 Pre_2     Failure                    1.873973 Low
# 2  0.3525093 -1.5438766 Pre_4     Failure                    3.991781 Low
# 3 -0.1031727  0.5201130 Pre_6     Sustained Unresponsiveness 1.419178 Low
# 4  0.2816024  0.8535709 Pre_9     Sustained Unresponsiveness 1.389041 Low
# 5  1.0001857  0.4563618 Pre_11    Failure                    1.567123 Low
# 6 -0.1929039 -1.5970746 Pre_14    Failure                    3.912329 High

# %%
options(repr.plot.width=10, repr.plot.height=7) #changing size
lancet_palette = pal_lancet()(2)

Figure1a = ggplot(saliva_umap_outcome_df, aes(x = X, y = Y, color = Outcome, shape = IgE)) + 
  geom_point(size = 3.5) + 
  geom_text_repel(aes(label = Sample_ID), 
                  segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.15) + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        legend.title = element_text(face = 'bold', size = 15), #changes legend title
        legend.text = element_text(size = 12), #changes legend text
        legend.position = "bottom", 
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

  labs(x = 'Dimension 1', y = 'Dimension 2') + #changing axis labels 

  scale_color_manual(values = rev(lancet_palette))

# %%
options(repr.plot.width=7, repr.plot.height=7) #changing size

unique_v1_saliva_df = unique(v1_saliva_df[,1:9])

Figure1b = ggplot(unique_v1_saliva_df, aes(x = Outcome, y = IgE, color = Outcome)) + 
  geom_boxplot() + 
  geom_point(position = position_jitter(w = 0.1), alpha = 0.8) + 

  # overall p value
  stat_compare_means(method = "wilcox.test", label = "p.format", 
                      label.x.npc = "right", size = 7, label.y = 150, label.x = 2) + 

  theme_light() + 
  theme(axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 12), #changing size of x axis labels
        legend.position = 'none', # removes legend
        plot.margin = unit(c(0,0,2,2), "lines"), # adding space at the bottom of the figure
        axis.title = element_text(face = "bold", size = rel(1.5))) + #changes axis titles
         
  labs(y = 'IgE (kU/L)') + #changing axis labels 
  scale_colour_manual(values = rev(lancet_palette))

# %%
Figure2a = ggplot(stool_umap_outcome_df, aes(x = X, y = Y, color = Outcome, shape = IgE)) + 
  geom_point(size = 3.5) + 
  geom_text_repel(aes(label = Sample_ID), 
                  segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.15) + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        legend.title = element_text(face = 'bold', size = 15), #changes legend title
        legend.text = element_text(size = 12), #changes legend text
        legend.position = "bottom", 
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

  labs(x = 'Dimension 1', y = 'Dimension 2') + #changing axis labels 

  scale_color_manual(values = rev(lancet_palette))

# %%
unique_v1_stool_df = unique(v1_stool_df[,1:9])

Figure2b = ggplot(unique_v1_stool_df, aes(x = Outcome, y = IgE, color = Outcome)) + 
  geom_boxplot() + 
  geom_point(position = position_jitter(w = 0.1), alpha = 0.8) + 

  # overall p value
  stat_compare_means(method = "wilcox.test", label = "p.format", 
                      label.x.npc = "right", size = 7, label.y = 150, label.x = 2) + 

  theme_light() + 
  theme(axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 12), #changing size of x axis labels
        legend.position = 'none', # removes legend
        plot.margin = unit(c(0,0,2,2), "lines"), # adding space at the bottom of the figure
        axis.title = element_text(face = "bold", size = rel(1.5))) + #changes axis titles
         
  labs(y = 'IgE (kU/L)') + #changing axis labels 
  scale_colour_manual(values = rev(lancet_palette))

# %%
options(repr.plot.width=20, repr.plot.height=7) #changing size
Figure1 = plot_grid(Figure1a, Figure1b,
                            # adding labels, changing size their size and position
                            labels = "AUTO", label_size = 20, label_x = 0.01, label_y = 0.99)
Figure1
# Out:
# plot without title

# %%
Figure2 = plot_grid(Figure2a, Figure2b,
                            # adding labels, changing size their size and position
                            labels = "AUTO", label_size = 20, label_x = 0.01, label_y = 0.99)
Figure2
# Out:
# plot without title

# %%
v1_saliva_df %>%
    tbl_summary(by = Outcome, missing = "no", 
    include = colnames(v1_saliva_df[6:8]), 
              statistic = list(all_continuous() ~ "{mean} ({sd})")) %>%
    add_n() %>% 
    add_p() %>% # adding p value
    as_tibble()
# Out:
#   **Characteristic** **N** **Failure**  \nN = 9
# 1 Age                19    2.86 (1.04)
# 2 IgE                19    55 (71)
#   **Sustained Unresponsiveness**  \nN = 10 **p-value**
# 1 2.36 (1.05)                              0.3
# 2 14 (35)                                  0.002

# %%
v1_stool_df %>%
    tbl_summary(by = Outcome, missing = "no", 
    include = colnames(v1_stool_df[7:9]), 
              statistic = list(all_continuous() ~ "{mean} ({sd})")) %>%
    add_n() %>% 
    add_p() %>% # adding p value
    as_tibble()
# Out:
#   **Characteristic** **N** **Failure**  \nN = 6
# 1 Age                16    2.87 (1.06)
# 2 IgE                16    80 (78)
#   **Sustained Unresponsiveness**  \nN = 10 **p-value**
# 1 2.15 (0.92)                              0.2
# 2 4 (4)                                    <0.001

# %% [markdown]
# In the saliva samples, there were similarities in the saliva microbiome profiles of participants prior to treatment. Additional statistics reveal that participants that went on to have sustained unresponsiveness had significantly lower IgE levels prior to treatment (p value < 0.05).
#
# In the stool samples, there were similarities in the stool microbiome profiles of participants prior to treatment. As with the saliva samples, participants that went on to have sustained unresponsiveness had significantly lower IgE levels prior to treatment (p value < 0.05).
#
# ## Comparing IgE levels before treatment

# %%
v2_saliva_df = combined_saliva_df %>%
    # only keep participants' baseline samples 
    filter(Time_Point == 'Pre') 

v2_stool_df = combined_stool_df %>%
     filter(Time_Point == 'Pre')

head(v2_saliva_df)
# Out:
#   Original_Sample_ID Subject_No Sample_ID Time_Point Treatment
# 1 FS01baseline       1          Pre_1     Pre        P
# 2 FS02baseline       2          Pre_2     Pre        A
# 3 FS04baseline       3          Pre_3     Pre        P
# 4 FS05baseline       4          Pre_4     Pre        A
# 5 FS06baseline       5          Pre_5     Pre        P
# 6 FS07baseline       6          Pre_6     Pre        A
#   Outcome                    Age      IgE    IgE_Binarized
# 1 Failure                    3.838356  41.00 High
# 2 Failure                    1.873973  14.20 Low
# 3 Failure                    3.715068  67.40 High
# 4 Failure                    3.991781   9.59 Low
# 5 Failure                    2.356164 106.00 High
# 6 Sustained Unresponsiveness 1.419178   1.32 Low
#   k__Bacteria.__.__.__.__.__.__ ⋯
# 1 2.1972246                     ⋯
# 2 0.6931472                     ⋯
# 3 1.7917595                     ⋯
# 4 3.2580965                     ⋯
# 5 4.4308168                     ⋯
# 6 2.1972246                     ⋯
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# 1 4.0775374
# 2 0.6931472
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# 1 2.7080502
# 2 0.6931472
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.s__aphrophilus
# 1 0.6931472
# 2 3.8712010
# 3 0.6931472
# 4 0.6931472
# 5 3.9512437
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.__
# 1 5.3706380
# 2 5.9215784
# 3 0.6931472
# 4 4.7184989
# 5 6.2441669
# 6 7.7480285
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.s__parainfluenzae
# 1 6.655440
# 2 8.119994
# 3 3.806662
# 4 7.112327
# 5 7.980708
# 6 7.590852
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# 1 0.6931472
# 2 0.6931472
# 3 6.0306853
# 4 3.7376696
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_347
# 1 2.7725887
# 2 0.6931472
# 3 3.8918203
# 4 1.7917595
# 5 0.6931472
# 6 2.8903718
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_352
# 1 5.5134287
# 2 0.6931472
# 3 0.6931472
# 4 6.0038871
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.3..s__bacterium_HMT_351
# 1 3.8286414
# 2 0.6931472
# 3 1.3862944
# 4 3.6109179
# 5 0.6931472
# 6 1.9459101
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.6..s__bacterium_HMT_870
# 1 4.1896547
# 2 4.7361984
# 3 6.9584484
# 4 5.1298987
# 5 0.6931472
# 6 3.4011974

# %%
# setting seed for reproducibility
set.seed(12)

saliva_umap_ige = umap(v2_saliva_df[,c(10:ncol(v2_saliva_df))], random_state = 12)
stool_umap_ige = umap(v2_stool_df[,c(11:ncol(v2_stool_df))], random_state = 12)

saliva_umap_ige_df = data.frame(X = saliva_umap_ige$layout[,1],
                     Y = saliva_umap_ige$layout[,2],
                     Sample_ID = v2_saliva_df$Sample_ID,
                     IgE = v2_saliva_df$IgE_Binarized,
                     Age = v2_saliva_df$Age) %>%
    mutate(IgE = factor(IgE, levels = c('Low', 'High'))) 

stool_umap_ige_df = data.frame(X = stool_umap_ige$layout[,1],
                     Y = stool_umap_ige$layout[,2],
                     Sample_ID = v2_stool_df$Sample_ID,
                     IgE = v2_stool_df$IgE_Binarized,
                     Age = v2_stool_df$Age) %>%
    mutate(IgE = factor(IgE, levels = c('Low', 'High'))) 

head(saliva_umap_ige_df)
# Out:
#   X          Y          Sample_ID IgE  Age
# 1  1.1463484 -0.4080687 Pre_1     High 3.838356
# 2 -0.3865497 -0.4928049 Pre_2     Low  1.873973
# 3 -1.4518215  1.5310854 Pre_3     High 3.715068
# 4  1.1542358 -0.9102363 Pre_4     Low  3.991781
# 5  0.3808392  0.6167579 Pre_5     High 2.356164
# 6 -1.3250287 -0.5672609 Pre_6     Low  1.419178

# %%
options(repr.plot.width=10, repr.plot.height=7) #changing size
futurama_palette = pal_futurama()(3)

ggplot(saliva_umap_ige_df, aes(x = X, y = Y, color = IgE)) + 
  geom_point(size = 3.5) + 
  geom_text_repel(aes(label = Sample_ID), 
                  segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.15) + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        legend.title = element_text(face = 'bold', size = 15), #changes legend title
        legend.text = element_text(size = 12), #changes legend text
        legend.position = "bottom", 
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

  labs(x = 'Dimension 1', y = 'Dimension 2') + #changing axis labels 

  scale_color_manual(values = futurama_palette[3:2])
# Out:
# plot without title

# %%
ggplot(stool_umap_ige_df, aes(x = X, y = Y, color = IgE)) + 
  geom_point(size = 3.5) + 
  geom_text_repel(aes(label = Sample_ID), 
                  segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.15) + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        legend.title = element_text(face = 'bold', size = 15), #changes legend title
        legend.text = element_text(size = 12), #changes legend text
        legend.position = "bottom", 
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

  labs(x = 'Dimension 1', y = 'Dimension 2') + #changing axis labels 

  scale_color_manual(values = futurama_palette[3:2])
# Out:
# plot without title

# %%
v2_saliva_df %>%
    tbl_summary(by = IgE_Binarized, missing = "no", 
    include = colnames(v2_saliva_df[7]), 
              statistic = list(all_continuous() ~ "{mean} ({sd})")) %>%
    add_n() %>% 
    add_p() %>% # adding p value
    as_tibble()
# Out:
# The following warnings were returned during `add_p()`:
# ! For variable `Age` (`IgE_Binarized`) and "estimate", "statistic", "p.value",
#   "conf.low", and "conf.high" statistics: cannot compute exact p-value with
#   ties
# ! For variable `Age` (`IgE_Binarized`) and "estimate", "statistic", "p.value",
#   "conf.low", and "conf.high" statistics: cannot compute exact confidence
#   intervals with ties
#   **Characteristic** **N** **High**  \nN = 14 **Low**  \nN = 21 **p-value**
# 1 Age                35    2.75 (0.99)        2.47 (0.97)       0.4

# %%
v2_stool_df %>%
    tbl_summary(by = IgE_Binarized, missing = "no", 
    include = colnames(v2_stool_df[8]), 
              statistic = list(all_continuous() ~ "{mean} ({sd})")) %>%
    add_n() %>% 
    add_p() %>% # adding p value
    as_tibble()
# Out:
#   **Characteristic** **N** **High**  \nN = 14 **Low**  \nN = 19 **p-value**
# 1 Age                33    2.58 (1.00)        2.26 (0.88)       0.4

# %% [markdown]
# # Comparing Microbiome Profiles after Undergoing Treatment
#
# Note: To maximize the sample size, I didn't require participants to have both pre and post samples.

# %%
`%notin%` <- Negate(`%in%`)

paired_saliva_df = saliva_df  %>%
    # removing those failed the IgE protein
    filter(IgE_Binarized != 'Fail')  %>%
    # ended up reassinging 'DS' to 'F' due to small sample size
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    mutate(across(c(10:ncol(saliva_df)), ~ log(.x + 2))) %>%
    # removing 13 participants that don't have pre and post samples
    # keeping subject 20, 24, 26 that have post but not pre data
    filter(#Subject_No %notin% c(1,12,13,16,17,31,32,36,37,43),
    # retaining those given treatment
          Treatment == 'A') %>%
    # cleaning variable names here
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

paired_stool_df = stool_df  %>%
    filter(IgE_Binarized != 'Fail') %>%
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    mutate(across(c(11:ncol(stool_df)), ~ log(.x + 2))) %>%
     # removing 10 participants that don't have pre and post samples
    # keeping subject 3, 10 that have post but not pre data
    filter(#Subject_No %notin% c(14,15,23,25,27,32,35,39),
          Treatment == 'A') %>%
    # cleaning variable names here
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

head(paired_saliva_df)
# Out:
#   Original_Sample_ID Subject_No Sample_ID Time_Point Treatment
# 1 FS0236mo           2          Post_2    Post       A
# 2 FS02baseline       2          Pre_2     Pre        A
# 3 FS0536mo           4          Post_4    Post       A
# 4 FS05baseline       4          Pre_4     Pre        A
# 5 FS0736mo           6          Post_6    Post       A
# 6 FS07baseline       6          Pre_6     Pre        A
#   Outcome                    Age      IgE   IgE_Binarized
# 1 Failure                    1.873973 14.20 Low
# 2 Failure                    1.873973 14.20 Low
# 3 Failure                    3.991781  9.59 Low
# 4 Failure                    3.991781  9.59 Low
# 5 Sustained Unresponsiveness 1.419178  1.32 Low
# 6 Sustained Unresponsiveness 1.419178  1.32 Low
#   k__Bacteria.__.__.__.__.__.__ ⋯
# 1 4.1743873                     ⋯
# 2 0.6931472                     ⋯
# 3 2.0794415                     ⋯
# 4 3.2580965                     ⋯
# 5 1.3862944                     ⋯
# 6 2.1972246                     ⋯
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# 1 6.5510803
# 2 0.6931472
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# 1 0.6931472
# 2 0.6931472
# 3 2.9444390
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.s__aphrophilus
# 1 3.8066625
# 2 3.8712010
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.__
# 1 4.605170
# 2 5.921578
# 3 4.948760
# 4 4.718499
# 5 6.142037
# 6 7.748029
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.s__parainfluenzae
# 1 7.413970
# 2 8.119994
# 3 7.833204
# 4 7.112327
# 5 7.407318
# 6 7.590852
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# 1 0.6931472
# 2 0.6931472
# 3 0.6931472
# 4 3.7376696
# 5 2.1972246
# 6 0.6931472
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_347
# 1 0.6931472
# 2 0.6931472
# 3 0.6931472
# 4 1.7917595
# 5 0.6931472
# 6 2.8903718
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_352
# 1 6.0520892
# 2 0.6931472
# 3 6.2225763
# 4 6.0038871
# 5 5.1298987
# 6 0.6931472
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.3..s__bacterium_HMT_351
# 1 4.9972123
# 2 0.6931472
# 3 3.7135721
# 4 3.6109179
# 5 4.1431347
# 6 1.9459101
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.6..s__bacterium_HMT_870
# 1 4.828314
# 2 4.736198
# 3 4.634729
# 4 5.129899
# 5 6.084499
# 6 3.401197

# %%
set.seed(12)

saliva_umap_paired = umap(paired_saliva_df[,c(10:ncol(paired_saliva_df))], random_state = 12)
stool_umap_paired = umap(paired_stool_df[,c(11:ncol(paired_stool_df))], random_state = 12)

saliva_umap_paired_df = data.frame(X = saliva_umap_paired$layout[,1],
                     Y = saliva_umap_paired$layout[,2],
                     Sample_ID = paired_saliva_df$Sample_ID,
                     Time_Point = paired_saliva_df$Time_Point,
                     Outcome = paired_saliva_df$Outcome,
                     Age = paired_saliva_df$Age,
                     IgE = paired_saliva_df$IgE_Binarized) %>%
    mutate(IgE = factor(IgE, levels = c('Low', 'High')),
          Time_Point = factor(Time_Point, levels = c('Pre', 'Post'))) 

stool_umap_paired_df = data.frame(X = stool_umap_paired$layout[,1],
                     Y = stool_umap_paired$layout[,2],
                     Sample_ID = paired_stool_df$Sample_ID,
                     Time_Point = paired_stool_df$Time_Point,
                     Outcome = paired_stool_df$Outcome,
                     Age = paired_stool_df$Age,
                     IgE = paired_stool_df$IgE_Binarized) %>%
    mutate(IgE = factor(IgE, levels = c('Low', 'High')),
          Time_Point = factor(Time_Point, levels = c('Pre', 'Post'))) 

head(saliva_umap_paired_df)
# Out:
#   X           Y         Sample_ID Time_Point Outcome
# 1  0.61058757  1.450683 Post_2    Post       Failure
# 2 -0.09464208 -1.666695 Pre_2     Pre        Failure
# 3  0.14125274  1.960445 Post_4    Post       Failure
# 4 -0.46696901  1.489053 Pre_4     Pre        Failure
# 5  0.19540536  1.365907 Post_6    Post       Sustained Unresponsiveness
# 6 -0.68054384 -2.095174 Pre_6     Pre        Sustained Unresponsiveness
#   Age      IgE
# 1 1.873973 Low
# 2 1.873973 Low
# 3 3.991781 Low
# 4 3.991781 Low
# 5 1.419178 Low
# 6 1.419178 Low

# %%
bmj_palette = pal_bmj()(2)

ggplot(saliva_umap_paired_df, aes(x = X, y = Y, color = Time_Point, shape = Outcome)) + 
  geom_point(size = 3.5) + 
  geom_text_repel(data = saliva_umap_paired_df, 
                  aes(x = X, y = Y, label = Sample_ID), 
                  segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.15) + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        legend.title = element_text(face = 'bold', size = 15), #changes legend title
        legend.text = element_text(size = 12), #changes legend text
        legend.position = "bottom", 
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

  labs(x = 'Dimension 1', y = 'Dimension 2') + #changing axis labels 

  scale_color_manual(name = 'Time Point', values = rev(bmj_palette))
# Out:
# plot without title

# %%
ggplot(stool_umap_paired_df, aes(x = X, y = Y, color = Time_Point, shape = Outcome)) + 
  geom_point(size = 3.5) + 
  geom_text_repel(data = stool_umap_paired_df, 
                  aes(x = X, y = Y,  label = Sample_ID), 
                  segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.15) + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        legend.title = element_text(face = 'bold', size = 15), #changes legend title
        legend.text = element_text(size = 12), #changes legend text
        legend.position = "bottom", 
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

  labs(x = 'Dimension 1', y = 'Dimension 2') + #changing axis labels 

  scale_color_manual(name = 'Time Point', values = rev(bmj_palette))
# Out:
# plot without title

# %%
paired_saliva_df2 = saliva_df  %>%
    # removing those failed the IgE protein
    filter(IgE_Binarized != 'Fail')  %>%
    # ended up reassinging 'DS' to 'F' due to small sample size
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    mutate(across(c(10:ncol(saliva_df)), ~ log(.x + 2))) %>%
    # removing 13 participants that don't have pre and post samples
    filter(Subject_No %notin% c(1,12,13,16,17,20,24,26,31,32,36,37,43),
    # retaining those given treatment
          Treatment == 'A') %>%
    # cleaning variable names here
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

paired_stool_df2 = stool_df  %>%
    filter(IgE_Binarized != 'Fail') %>%
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    mutate(across(c(11:ncol(stool_df)), ~ log(.x + 2))) %>%
    # removing 10 participants that don't have pre and post samples
    filter(Subject_No %notin% c(3,10,14,15,23,25,27,32,35,39),
          Treatment == 'A') %>%
    # cleaning variable names here
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

head(paired_saliva_df2)
# Out:
#   Original_Sample_ID Subject_No Sample_ID Time_Point Treatment
# 1 FS0236mo           2          Post_2    Post       A
# 2 FS02baseline       2          Pre_2     Pre        A
# 3 FS0536mo           4          Post_4    Post       A
# 4 FS05baseline       4          Pre_4     Pre        A
# 5 FS0736mo           6          Post_6    Post       A
# 6 FS07baseline       6          Pre_6     Pre        A
#   Outcome                    Age      IgE   IgE_Binarized
# 1 Failure                    1.873973 14.20 Low
# 2 Failure                    1.873973 14.20 Low
# 3 Failure                    3.991781  9.59 Low
# 4 Failure                    3.991781  9.59 Low
# 5 Sustained Unresponsiveness 1.419178  1.32 Low
# 6 Sustained Unresponsiveness 1.419178  1.32 Low
#   k__Bacteria.__.__.__.__.__.__ ⋯
# 1 4.1743873                     ⋯
# 2 0.6931472                     ⋯
# 3 2.0794415                     ⋯
# 4 3.2580965                     ⋯
# 5 1.3862944                     ⋯
# 6 2.1972246                     ⋯
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# 1 6.5510803
# 2 0.6931472
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# 1 0.6931472
# 2 0.6931472
# 3 2.9444390
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.s__aphrophilus
# 1 3.8066625
# 2 3.8712010
# 3 0.6931472
# 4 0.6931472
# 5 0.6931472
# 6 0.6931472
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.__
# 1 4.605170
# 2 5.921578
# 3 4.948760
# 4 4.718499
# 5 6.142037
# 6 7.748029
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.s__parainfluenzae
# 1 7.413970
# 2 8.119994
# 3 7.833204
# 4 7.112327
# 5 7.407318
# 6 7.590852
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# 1 0.6931472
# 2 0.6931472
# 3 0.6931472
# 4 3.7376696
# 5 2.1972246
# 6 0.6931472
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_347
# 1 0.6931472
# 2 0.6931472
# 3 0.6931472
# 4 1.7917595
# 5 0.6931472
# 6 2.8903718
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_352
# 1 6.0520892
# 2 0.6931472
# 3 6.2225763
# 4 6.0038871
# 5 5.1298987
# 6 0.6931472
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.3..s__bacterium_HMT_351
# 1 4.9972123
# 2 0.6931472
# 3 3.7135721
# 4 3.6109179
# 5 4.1431347
# 6 1.9459101
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.6..s__bacterium_HMT_870
# 1 4.828314
# 2 4.736198
# 3 4.634729
# 4 5.129899
# 5 6.084499
# 6 3.401197

# %% [markdown]
# ## Outcome Differences based on Significant Bacteria
# Need to obtain log2 FC between pre and post samples for each subject for significant bacteria only.

# %%
# getting FC
log_saliva_df = lag(paired_saliva_df2[,10:ncol(saliva_df)])/paired_saliva_df2[,10:ncol(saliva_df)]
log_saliva_df = log_saliva_df[seq_len(nrow(log_saliva_df)) %% 2 == 0, ]
log2FC_saliva_df = cbind(paired_saliva_df2[,c(2,6:9)] %>%
                               unique() %>% 
                               remove_rownames, log_saliva_df)

log_stool_df = lag(paired_stool_df2[,11:ncol(stool_df)])/paired_stool_df2[,11:ncol(stool_df)]
log_stool_df = log_stool_df[seq_len(nrow(log_stool_df)) %% 2 == 0, ]
log2FC_stool_df = cbind(paired_stool_df2[,c(3,7:10)] %>%
                               unique() %>% 
                               remove_rownames, log_stool_df)

head(log2FC_saliva_df)
# Out:
#    Subject_No Outcome                    Age      IgE    IgE_Binarized
# 2   2         Failure                    1.873973  14.20 Low
# 4   4         Failure                    3.991781   9.59 Low
# 6   6         Sustained Unresponsiveness 1.419178   1.32 Low
# 8   9         Sustained Unresponsiveness 1.389041   0.42 Low
# 10 11         Failure                    1.567123   4.34 Low
# 12 14         Failure                    3.912329 105.00 High
#    k__Bacteria.__.__.__.__.__.__
# 2  6.0223678
# 4  0.6382382
# 6  0.6309298
# 8  1.1005724
# 10 1.4771213
# 12 1.9534453
#    k__Bacteria.p__Absconditabacteria_.SR1..c__Absconditabacteria_.SR1._.C.1..o__Absconditabacteria_.SR1._.O.1..f__Absconditabacteria_.SR1._.F.1..g__Absconditabacteria_.SR1._.G.1..s__bacterium_HMT_874
# 2  1.140281
# 4  1.000000
# 6  4.700440
# 8  1.000000
# 10 3.807355
# 12 1.000000
#    k__Bacteria.p__Absconditabacteria_.SR1..c__Absconditabacteria_.SR1._.C.1..o__Absconditabacteria_.SR1._.O.1..f__Absconditabacteria_.SR1._.F.1..g__Absconditabacteria_.SR1._.G.1..s__bacterium_HMT_875
# 2  8.647458
# 4  1.623249
# 6  1.000000
# 8  1.000000
# 10 1.000000
# 12 1.000000
#    k__Bacteria.p__Actinobacteria.c__Actinomycetia.o__Actinomycetales.f__Actinomycetaceae.g__Actinomyces.__
# 2  1.0888268
# 4  0.7974088
# 6  1.0305566
# 8  1.4281986
# 10 1.5424305
# 12 0.9052225
#    k__Bacteria.p__Actinobacteria.c__Actinomycetia.o__Actinomycetales.f__Actinomycetaceae.g__Actinomyces.s__graevenitzii
# 2  1.2622362
# 4  1.1740045
# 6  1.5563025
# 8  8.0056245
# 10 2.0714662
# 12 0.8867124
#    ⋯
# 2  ⋯
# 4  ⋯
# 6  ⋯
# 8  ⋯
# 10 ⋯
# 12 ⋯
#    k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# 2  9.451211
# 4  1.000000
# 6  1.000000
# 8  1.000000
# 10 1.000000
# 12 1.755875
#    k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# 2  1.000000
# 4  4.247928
# 6  1.000000
# 8  1.000000
# 10 1.000000
# 12 1.000000
#    k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.s__aphrophilus
# 2  0.9833286
# 4  1.0000000
# 6  1.0000000
# 8  1.0000000
# 10 1.0000000
# 12 1.0000000
#    k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.__
# 2  0.7776930
# 4  1.0487996
# 6  0.7927226
# 8  0.5133670
# 10 2.2108715
# 12 1.8356838
#    k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.s__parainfluenzae
# 2  0.9130512
# 4  1.1013559
# 6  0.9758216
# 8  0.9129980
# 10 1.0270003
# 12 1.4479534
#    k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# 2  1.000000
# 4  0.185449
# 6  3.169925
# 8  2.584963
# 10 1.000000
# 12 1.000000
#    k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_347
# 2  1.0000000
# 4  0.3868528
# 6  0.2398125
# 8  1.0000000
# 10 1.0000000
# 12 1.0000000
#    k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_352
# 2  8.7313190
# 4  1.0364246
# 6  7.4008794
# 8  8.9158794
# 10 1.7658363
# 12 0.8403361
#    k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.3..s__bacterium_HMT_351
# 2  7.209453
# 4  1.028429
# 6  2.129150
# 8  4.643856
# 10 1.952672
# 12 1.244094
#    k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.6..s__bacterium_HMT_870
# 2  1.0194492
# 4  0.9034738
# 6  1.7889286
# 8  2.7702106
# 10 1.5892510
# 12 0.1707073

# %%
v3_saliva_df = log2FC_saliva_df %>%
    pivot_longer(cols = 6:ncol(log2FC_saliva_df), names_to = 'Name', values_to = 'log2FC') %>%
    filter(Name %in% saliva_paired_outcome_df$Name) %>%
    pivot_wider(names_from = Name, values_from = log2FC)

v3_stool_df = log2FC_stool_df %>%
    pivot_longer(cols = 6:ncol(log2FC_stool_df), names_to = 'Name', values_to = 'log2FC') %>%
    filter(Name %in% stool_paired_outcome_df$Name) %>%
    pivot_wider(names_from = Name, values_from = log2FC)


head(v3_saliva_df)
# Out:
#   Subject_No Outcome                    Age      IgE    IgE_Binarized
# 1  2         Failure                    1.873973  14.20 Low
# 2  4         Failure                    3.991781   9.59 Low
# 3  6         Sustained Unresponsiveness 1.419178   1.32 Low
# 4  9         Sustained Unresponsiveness 1.389041   0.42 Low
# 5 11         Failure                    1.567123   4.34 Low
# 6 14         Failure                    3.912329 105.00 High
#   k__Bacteria.p__Actinobacteria.c__Actinomycetia.o__Corynebacteriales.f__Corynebacteriaceae.g__Corynebacterium.s__amycolatum
# 1 1.0
# 2 1.0
# 3 1.0
# 4 0.5
# 5 1.0
# 6 1.0
#   k__Bacteria.p__Actinobacteria.c__Actinomycetia.o__Propionibacteriales.f__Propionibacteriaceae.g__Arachnia.s__propionica
# 1 1.0000000
# 2 1.0000000
# 3 0.3154649
# 4 1.0000000
# 5 1.0000000
# 6 0.3010300
#   k__Bacteria.p__Actinobacteria.c__Actinomycetia.o__Propionibacteriales.f__Propionibacteriaceae.g__Arachnia.s__rubra
# 1 1.000000
# 2 3.000000
# 3 4.754888
# 4 1.000000
# 5 1.000000
# 6 1.000000
#   k__Bacteria.p__Bacteroidetes.c__Bacteroidia.o__Bacteroidales.f__Prevotellaceae.g__Alloprevotella.s__sp._HMT_308
# 1 1.298568
# 2 6.599913
# 3 1.000000
# 4 7.434628
# 5 8.154818
# 6 1.161721
#   k__Bacteria.p__Bacteroidetes.c__Flavobacteriia.o__Flavobacteriales.f__Flavobacteriaceae.g__Capnocytophaga.s__sp._HMT_338
# 1 1.000000
# 2 1.000000
# 3 4.807355
# 4 1.000000
# 5 1.000000
# 6 3.584963
#   ⋯
# 1 ⋯
# 2 ⋯
# 3 ⋯
# 4 ⋯
# 5 ⋯
# 6 ⋯
#   k__Bacteria.p__Firmicutes.c__Clostridia.o__Eubacteriales.f__Lachnospiraceae.g__Stomatobaculum.s__longum
# 1 1.0000000
# 2 1.3022969
# 3 1.0000000
# 4 5.4594316
# 5 1.0000000
# 6 0.2446505
#   k__Bacteria.p__Firmicutes.c__Negativicutes.o__Selenomonadales.f__Selenomonadaceae.g__Selenomonas.s__artemidis
# 1 1.322219
# 2 0.301030
# 3 1.000000
# 4 3.459432
# 5 1.000000
# 6 1.000000
#   k__Bacteria.p__Firmicutes.c__Negativicutes.o__Veillonellales.f__Veillonellaceae.g__Veillonella.s__dispar
# 1 0.9328649
# 2 1.0000000
# 3 1.0000000
# 4 6.4918531
# 5 6.9068906
# 6 1.0000000
#   k__Bacteria.p__Fusobacteria.c__Fusobacteriia.o__Fusobacteriales.f__Leptotrichiaceae.g__Pseudoleptotrichia.__
# 1 0.13082402
# 2 1.00000000
# 3 0.09247459
# 4 1.00000000
# 5 0.10451553
# 6 4.58496250
#   k__Bacteria.p__Fusobacteria.c__Fusobacteriia.o__Fusobacteriales.f__Leptotrichiaceae.g__Pseudoleptotrichia.s__sp._HMT_221
# 1 4.169925
# 2 2.151493
# 3 8.467606
# 4 6.129283
# 5 7.651052
# 6 1.222281
#   k__Bacteria.p__Proteobacteria.c__Betaproteobacteria.o__Neisseriales.f__Neisseriaceae.g__Neisseria.s__oralis
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1
#   k__Bacteria.p__Proteobacteria.c__Betaproteobacteria.o__Neisseriales.f__Neisseriaceae.g__Neisseria.s__sp._HMT_018
# 1 0.1866524
# 2 1.0000000
# 3 1.0000000
# 4 3.0000000
# 5 1.0000000
# 6 1.0000000
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# 1 9.451211
# 2 1.000000
# 3 1.000000
# 4 1.000000
# 5 1.000000
# 6 1.755875
#   k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# 1 1.000000
# 2 4.247928
# 3 1.000000
# 4 1.000000
# 5 1.000000
# 6 1.000000
#   k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# 1 1.000000
# 2 0.185449
# 3 3.169925
# 4 2.584963
# 5 1.000000
# 6 1.000000

# %%
saliva_umap_sig_outcome = umap(v3_saliva_df[,c(6:ncol(v3_saliva_df))], n_neighbors = 10, random_state = 12)
stool_umap_sig_outcome = umap(v3_stool_df[,c(6:ncol(v3_stool_df))], n_neighbors = 10, random_state = 12)

saliva_umap_sig_outcome_df = data.frame(X = saliva_umap_sig_outcome$layout[,1],
                     Y = saliva_umap_sig_outcome$layout[,2],
                     Subject_No = v3_saliva_df$Subject_No,
                     Outcome = v3_saliva_df$Outcome,
                     Age = v3_saliva_df$Age) 

stool_umap_sig_outcome_df = data.frame(X = stool_umap_sig_outcome$layout[,1],
                     Y = stool_umap_sig_outcome$layout[,2],
                     Subject_No = v3_stool_df$Subject_No,
                     Outcome = v3_stool_df$Outcome,
                     Age = v3_stool_df$Age) 

head(saliva_umap_sig_outcome_df)
# Out:
#   X           Y          Subject_No Outcome                    Age
# 1  0.22463214 -1.1509468  2         Failure                    1.873973
# 2  0.85001875  0.3381059  4         Failure                    3.991781
# 3  0.05885131 -0.4234831  6         Sustained Unresponsiveness 1.419178
# 4  1.09186591  1.1804977  9         Sustained Unresponsiveness 1.389041
# 5  1.38785003  0.7362882 11         Failure                    1.567123
# 6 -0.50266794  0.5958405 14         Failure                    3.912329

# %%
Figure5a = ggplot(saliva_umap_sig_outcome_df, aes(x = X, y = Y, color = Outcome)) + 
  geom_point(size = 3.5) + 
  geom_text_repel(aes(label = Subject_No), 
                  segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.15) + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        legend.title = element_text(face = 'bold', size = 15), #changes legend title
        legend.text = element_text(size = 12), #changes legend text
        legend.position = "bottom", 
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

  labs(x = 'Dimension 1', y = 'Dimension 2') + #changing axis labels 

  scale_color_manual(values = rev(lancet_palette))

# %%
unique_v3_saliva_df = unique(v3_saliva_df[,1:9])

Figure5b = ggplot(unique_v3_saliva_df, aes(x = Outcome, y = IgE, color = Outcome)) + 
  geom_boxplot() + 
  geom_point(position = position_jitter(w = 0.1), alpha = 0.8) + 

  # overall p value
  stat_compare_means(method = "wilcox.test", label = "p.format", 
                      label.x.npc = "right", size = 7, label.y = 150, label.x = 2) + 

  theme_light() + 
  theme(axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 12), #changing size of x axis labels
        legend.position = 'none', # removes legend
        plot.margin = unit(c(0,0,2,2), "lines"), # adding space at the bottom of the figure
        axis.title = element_text(face = "bold", size = rel(1.5))) + #changes axis titles
         
  labs(y = 'IgE (kU/L)') + #changing axis labels 
  scale_colour_manual(values = rev(lancet_palette))

# %%
Figure6a = ggplot(stool_umap_sig_outcome_df, aes(x = X, y = Y, color = Outcome)) + 
  geom_point(size = 3.5) + 
  geom_text_repel(aes(label = Subject_No), 
                  segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.15) + 

  theme_light() + 
  theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
        axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 13), #changing size of x axis labels
        legend.title = element_text(face = 'bold', size = 15), #changes legend title
        legend.text = element_text(size = 12), #changes legend text
        legend.position = "bottom", 
        legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
        axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
        strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
        strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

  labs(x = 'Dimension 1', y = 'Dimension 2') + #changing axis labels 

  scale_color_manual(values = rev(lancet_palette))

# %%
unique_v3_stool_df = unique(v3_stool_df[,1:9])

Figure6b = ggplot(unique_v3_stool_df, aes(x = Outcome, y = IgE, color = Outcome)) + 
  geom_boxplot() + 
  geom_point(position = position_jitter(w = 0.1), alpha = 0.8) + 

  # overall p value
  stat_compare_means(method = "wilcox.test", label = "p.format", 
                      label.x.npc = "right", size = 7, label.y = 150, label.x = 2) + 

  theme_light() + 
  theme(axis.line = element_line(colour = "black"), #making x and y axes black
        axis.text = element_text(size = 12), #changing size of x axis labels
        legend.position = 'none', # removes legend
        plot.margin = unit(c(0,0,2,2), "lines"), # adding space at the bottom of the figure
        axis.title = element_text(face = "bold", size = rel(1.5))) + #changes axis titles
         
  labs(y = 'IgE (kU/L)') + #changing axis labels 
  scale_colour_manual(values = rev(lancet_palette))

# %%
options(repr.plot.width=20, repr.plot.height=7) #changing size
Figure5 = plot_grid(Figure5a, Figure5b,
                            # adding labels, changing size their size and position
                            labels = "AUTO", label_size = 20, label_x = 0.01, label_y = 0.99)
Figure5
# Out:
# plot without title

# %%
Figure6 = plot_grid(Figure6a, Figure6b,
                            # adding labels, changing size their size and position
                            labels = "AUTO", label_size = 20, label_x = 0.01, label_y = 0.99)
Figure6
# Out:
# plot without title

# %% [markdown]
# Running additional statistics to quantify trends I'm seeing.

# %%
v3_saliva_df %>%
    tbl_summary(by = Outcome, missing = "no", 
    include = colnames(v3_saliva_df[2:4]), 
              statistic = list(all_continuous() ~ "{mean} ({sd})",
                               all_categorical() ~ "{n} ({p}%)")) %>%
    add_n() %>% 
    add_p(test = list(#all_continuous() ~ "ancova.test",
                    all_categorical() ~ "fisher.test")) %>% # adding p value from anova
    as_tibble()
# Out:
#   **Characteristic** **N** **Failure**  \nN = 7
# 1 Age                16    3.07 (0.98)
# 2 IgE                16    69 (76)
#   **Sustained Unresponsiveness**  \nN = 9 **p-value**
# 1 2.44 (1.08)                             0.2
# 2 2 (2)                                   <0.001

# %%
v3_stool_df %>%
    tbl_summary(by = Outcome, missing = "no", 
    include = colnames(v3_stool_df[2:4]), 
              statistic = list(all_continuous() ~ "{mean} ({sd})",
                               all_categorical() ~ "{n} ({p}%)")) %>%
    add_n() %>% 
    add_p(test = list(#all_continuous() ~ "ancova.test",
                    all_categorical() ~ "fisher.test")) %>% # adding p value from anova
    as_tibble()
# Out:
#   **Characteristic** **N** **Failure**  \nN = 4
# 1 Age                12    3.10 (0.91)
# 2 IgE                12    72 (70)
#   **Sustained Unresponsiveness**  \nN = 8 **p-value**
# 1 2.10 (0.81)                             0.073
# 2 4 (5)                                   0.008

# %% [markdown]
# What we're capturing here is a shift in the microbiome, specifically in stool samples, which may suggest that treatment may shift the stool microbiome enough to be associated with sustained unresponsiveness.
#
# In the saliva samples, there is no clear clustering between subjects' outcome based on their log2 fold changes before and after treatment. Additional statistics reveal that there were significant differences in IgE concentrations with participants that went on to have sustained unresponsiveness having lower IgE levels prior to treatment (p value < 0.05).
#
# In the stool samples, there do seem to be differences in global microbiome changes after treatment between subjects' outcome. However, additonal statistics reveal that there were significant differences in IgE concentrations with participants that went on to have sustained unresponsiveness having lower IgE levels prior to treatment (p value < 0.05). The differences in ages of the participants was almost significant (p value < 0.1).
#
# Further research is needed to tease out the association and intersection between the significantly different bacteria, age, and IgE concentrations. REVISE!!
