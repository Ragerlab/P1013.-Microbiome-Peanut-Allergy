# %%
Output = ('/Users/alexis/Library/CloudStorage/OneDrive-UniversityofNorthCarolinaatChapelHill/CEMALB_DataAnalysisPM/Projects/P1013. Microbiome Peanut Allergy/P1013.3. Analyses/P1013.4. Outcome Prediction/Output')
cur_date = "111125"

library(readxl)
library(tidyverse)
library(factoextra)
# library(gtsummary)
# library(caret)
# library(e1071)
library(Hmisc)
# library(randomForest)
# library(pROC)
# library(themis)
library(ggsci)
library(ggrepel)

# reading in files
saliva_df = data.frame(read_excel("Input/Processed_Saliva_Data_090525.xlsx")) %>%
    mutate(Age = as.numeric(Age), IgE = as.numeric(IgE)) 
stool_df = data.frame(read_excel("Input/Processed_Stool_Data_090525.xlsx")) %>%
    mutate(Age = as.numeric(Age), IgE = as.numeric(IgE))
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     src, summarize
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units

# %%
`%notin%` <- Negate(`%in%`)

paired_saliva_df = saliva_df  %>%
    # removing those failed the IgE protein
    filter(IgE_Binarized != 'Fail')  %>%
    # ended up reassinging 'DS' to 'F' due to small sample size
     mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    # removing 13 participants that don't have pre and post samples
    # keeping subject 20, 24, 26 that have post but not pre data
    filter(#Subject_No %notin% c(1,12,13,16,17,31,32,36,37,43),
    # retaining those given treatment
          Treatment == 'A') %>%
    # normalizing
    mutate(across(10:ncol(saliva_df), ~ log(.x + 2))) %>%
    column_to_rownames('Sample_ID') %>%
    # cleaning variable names here
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

paired_stool_df = stool_df  %>%
    filter(IgE_Binarized != 'Fail') %>%
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
     # removing 10 participants that don't have pre and post samples
    # keeping subject 3, 10 that have post but not pre data
    filter(#Subject_No %notin% c(14,15,23,25,27,32,35,39),
          Treatment == 'A') %>%
    mutate(across(11:ncol(stool_df), ~ log(.x + 2))) %>%
    column_to_rownames('Sample_ID') %>%
    # cleaning variable names here
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

head(paired_saliva_df)
# Out:
#        Original_Sample_ID Subject_No Time_Point Treatment
# Post_2 FS0236mo           2          Post       A
# Pre_2  FS02baseline       2          Pre        A
# Post_4 FS0536mo           4          Post       A
# Pre_4  FS05baseline       4          Pre        A
# Post_6 FS0736mo           6          Post       A
# Pre_6  FS07baseline       6          Pre        A
#        Outcome                    Age      IgE   IgE_Binarized
# Post_2 Failure                    1.873973 14.20 Low
# Pre_2  Failure                    1.873973 14.20 Low
# Post_4 Failure                    3.991781  9.59 Low
# Pre_4  Failure                    3.991781  9.59 Low
# Post_6 Sustained Unresponsiveness 1.419178  1.32 Low
# Pre_6  Sustained Unresponsiveness 1.419178  1.32 Low
#        k__Bacteria.__.__.__.__.__.__
# Post_2 4.1743873
# Pre_2  0.6931472
# Post_4 2.0794415
# Pre_4  3.2580965
# Post_6 1.3862944
# Pre_6  2.1972246
#        k__Bacteria.p__Absconditabacteria_.SR1..c__Absconditabacteria_.SR1._.C.1..o__Absconditabacteria_.SR1._.O.1..f__Absconditabacteria_.SR1._.F.1..g__Absconditabacteria_.SR1._.G.1..s__bacterium_HMT_874
# Post_2 3.2958369
# Pre_2  2.8903718
# Post_4 0.6931472
# Pre_4  0.6931472
# Post_6 3.2580965
# Pre_6  0.6931472
#        ⋯
# Post_2 ⋯
# Pre_2  ⋯
# Post_4 ⋯
# Pre_4  ⋯
# Post_6 ⋯
# Pre_6  ⋯
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# Post_2 6.5510803
# Pre_2  0.6931472
# Post_4 0.6931472
# Pre_4  0.6931472
# Post_6 0.6931472
# Pre_6  0.6931472
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# Post_2 0.6931472
# Pre_2  0.6931472
# Post_4 2.9444390
# Pre_4  0.6931472
# Post_6 0.6931472
# Pre_6  0.6931472
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.s__aphrophilus
# Post_2 3.8066625
# Pre_2  3.8712010
# Post_4 0.6931472
# Pre_4  0.6931472
# Post_6 0.6931472
# Pre_6  0.6931472
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.__
# Post_2 4.605170
# Pre_2  5.921578
# Post_4 4.948760
# Pre_4  4.718499
# Post_6 6.142037
# Pre_6  7.748029
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.s__parainfluenzae
# Post_2 7.413970
# Pre_2  8.119994
# Post_4 7.833204
# Pre_4  7.112327
# Post_6 7.407318
# Pre_6  7.590852
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# Post_2 0.6931472
# Pre_2  0.6931472
# Post_4 0.6931472
# Pre_4  3.7376696
# Post_6 2.1972246
# Pre_6  0.6931472
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_347
# Post_2 0.6931472
# Pre_2  0.6931472
# Post_4 0.6931472
# Pre_4  1.7917595
# Post_6 0.6931472
# Pre_6  2.8903718
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_352
# Post_2 6.0520892
# Pre_2  0.6931472
# Post_4 6.2225763
# Pre_4  6.0038871
# Post_6 5.1298987
# Pre_6  0.6931472
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.3..s__bacterium_HMT_351
# Post_2 4.9972123
# Pre_2  0.6931472
# Post_4 3.7135721
# Pre_4  3.6109179
# Post_6 4.1431347
# Pre_6  1.9459101
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.6..s__bacterium_HMT_870
# Post_2 4.828314
# Pre_2  4.736198
# Post_4 4.634729
# Pre_4  5.129899
# Post_6 6.084499
# Pre_6  3.401197

# %% [markdown]
# # PCA based on Time Point recieving Active Treatment
#
# Note: For this analysis, I included participants that only pre or post data to maximize the sample size.

# %%
# setting seed for reproducibility
set.seed(12)

pca_saliva_df = paired_saliva_df[,9:ncol(paired_saliva_df)]
pca_stool_df = paired_stool_df[,10:ncol(paired_stool_df)]

# running pca 
saliva_pca = prcomp(pca_saliva_df)#, center = TRUE, scale = TRUE)
stool_pca = prcomp(pca_stool_df)#, center = TRUE, scale = TRUE)

# looking at a scree plot to see how much of the variance was captured in the first 2 eigenvectors
options(repr.plot.width = 10, repr.plot.height = 5) #changing size
fviz_eig(saliva_pca, addlabels = TRUE)
fviz_eig(stool_pca, addlabels = TRUE)
# Out:
# plot without title
# plot without title

# %%
options(repr.plot.width=12, repr.plot.height=7) #changing size
fviz_pca_ind(saliva_pca, 
             col.ind = paired_saliva_df$Time_Point, # color by Group
             palette = 'jco',
             #adding 95% confidence ellipses for each group
             addEllipses = TRUE, # Concentration ellipses
             ellipse.type = "confidence",
             repel = TRUE, title = "") +
    theme(axis.line = element_line(colour = "black"), #making x and y axes black
      legend.text = element_text(size = 12),
      legend.position = 'bottom',
      axis.title = element_text(face = "bold", size = rel(1.3))) #changes axis titles
# Out:
# plot without title

# %%
fviz_pca_ind(stool_pca, 
             col.ind = paired_stool_df$Time_Point, # color by Group
             palette = 'jco',
             #adding 95% confidence ellipses for each group
             addEllipses = TRUE, # Concentration ellipses
             ellipse.type = "confidence",
             repel = TRUE, title = "") +
    theme(axis.line = element_line(colour = "black"), #making x and y axes black
      legend.text = element_text(size = 12),
      legend.position = 'bottom',
      axis.title = element_text(face = "bold", size = rel(1.3))) #changes axis titles
# Out:
# plot without title

# %%
outlier_detection = function(pca_df){
    # """
    # Creating a scoring function for to detect PCA subject outliers. 
    # :param (input): PCA df (df)
    # :output: outlier names
    # """
    
    # getting scores
    scores = pca_df$x[,1:2]
    # identifying samples that are > 6 standard deviations away from the mean
    outlier_indices = apply(scores, 2, function(x) which( abs(x - mean(x)) > (6 * sd(x)) )) %>%
        Reduce(union, .)
    # getting sample names
    outliers = rownames(scores)[outlier_indices]
    
    return(outliers)
}

# calling fn
subject_outliers_saliva = outlier_detection(saliva_pca)
subject_outliers_stool = outlier_detection(stool_pca)            
subject_outliers_saliva
subject_outliers_stool
# Out:
# character(0)
# character(0)

# %% [markdown]
# # Comparing Baseline Bacteria Abundances

# %%
combined_saliva_df = saliva_df  %>%
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    filter(IgE_Binarized != 'Fail') %>%
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))
combined_stool_df = stool_df  %>%
    mutate(Outcome = ifelse(Outcome == 'DS', 'F', Outcome)) %>%
    filter(IgE_Binarized != 'Fail') %>%
    mutate(Outcome = ifelse(Outcome == "F", "Failure",
                                  ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

v1_saliva_df = combined_saliva_df %>%
    # only keep participants' baseline samples and those given active treatment
    filter(Time_Point == 'Pre' & Treatment == 'A') %>%
    # making the row names the sample ids
    column_to_rownames(var = 'Sample_ID') 

v1_stool_df = combined_stool_df %>%
    filter(Time_Point == 'Pre' & Treatment == 'A') %>%
    column_to_rownames(var = 'Sample_ID') 

head(v1_saliva_df)
# Out:
#        Original_Sample_ID Subject_No Time_Point Treatment
# Pre_2  FS02baseline        2         Pre        A
# Pre_4  FS05baseline        4         Pre        A
# Pre_6  FS07baseline        6         Pre        A
# Pre_9  FS10baseline        9         Pre        A
# Pre_11 FS12baseline       11         Pre        A
# Pre_14 FS15baseline       14         Pre        A
#        Outcome                    Age      IgE    IgE_Binarized
# Pre_2  Failure                    1.873973  14.20 Low
# Pre_4  Failure                    3.991781   9.59 Low
# Pre_6  Sustained Unresponsiveness 1.419178   1.32 Low
# Pre_9  Sustained Unresponsiveness 1.389041   0.42 Low
# Pre_11 Failure                    1.567123   4.34 Low
# Pre_14 Failure                    3.912329 105.00 High
#        k__Bacteria.__.__.__.__.__.__
# Pre_2   0
# Pre_4  24
# Pre_6   7
# Pre_9   9
# Pre_11  8
# Pre_14  2
#        k__Bacteria.p__Absconditabacteria_.SR1..c__Absconditabacteria_.SR1._.C.1..o__Absconditabacteria_.SR1._.O.1..f__Absconditabacteria_.SR1._.F.1..g__Absconditabacteria_.SR1._.G.1..s__bacterium_HMT_874
# Pre_2  16
# Pre_4   0
# Pre_6   0
# Pre_9   0
# Pre_11  0
# Pre_14  0
#        ⋯
# Pre_2  ⋯
# Pre_4  ⋯
# Pre_6  ⋯
# Pre_9  ⋯
# Pre_11 ⋯
# Pre_14 ⋯
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# Pre_2  0
# Pre_4  0
# Pre_6  0
# Pre_9  0
# Pre_11 0
# Pre_14 8
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# Pre_2  0
# Pre_4  0
# Pre_6  0
# Pre_9  0
# Pre_11 0
# Pre_14 0
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.s__aphrophilus
# Pre_2  46
# Pre_4   0
# Pre_6   0
# Pre_9   0
# Pre_11  0
# Pre_14  0
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.__
# Pre_2   371
# Pre_4   110
# Pre_6  2315
# Pre_9  1450
# Pre_11   16
# Pre_14   33
#        k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.s__parainfluenzae
# Pre_2  3359
# Pre_4  1225
# Pre_6  1978
# Pre_9  4274
# Pre_11 4652
# Pre_14  262
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# Pre_2   0
# Pre_4  40
# Pre_6   0
# Pre_9   0
# Pre_11  0
# Pre_14  0
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_347
# Pre_2   0
# Pre_4   4
# Pre_6  16
# Pre_9   0
# Pre_11  0
# Pre_14  0
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_352
# Pre_2     0
# Pre_4   403
# Pre_6     0
# Pre_9     0
# Pre_11   37
# Pre_14 1465
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.3..s__bacterium_HMT_351
# Pre_2   0
# Pre_4  35
# Pre_6   5
# Pre_9   0
# Pre_11  7
# Pre_14 58
#        k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.6..s__bacterium_HMT_870
# Pre_2  112
# Pre_4  167
# Pre_6   28
# Pre_9    7
# Pre_11  31
# Pre_14  56

# %%
# setting seed for reproducibility
set.seed(12)

pca_saliva_df = v1_saliva_df[,9:ncol(v1_saliva_df)]
pca_stool_df = v1_stool_df[,10:ncol(v1_stool_df)]

# running pca 
saliva_pca = prcomp(pca_saliva_df)#, center = TRUE, scale = TRUE)
stool_pca = prcomp(pca_stool_df)#, center = TRUE, scale = TRUE)

# looking at a scree plot to see how much of the variance was captured in the first 2 eigenvectors
options(repr.plot.width = 10, repr.plot.height = 5) #changing size
fviz_eig(saliva_pca, addlabels = TRUE)
fviz_eig(stool_pca, addlabels = TRUE)
# Out:
# plot without title
# plot without title

# %%
# saliva_baseline_pca_df = data.frame(saliva_pca$x[,1:2]) %>%
#                rownames_to_column(var = "SampleID")
# stool_baseline_pca_df = data.frame(stool_pca$x[,1:2]) %>%
#                rownames_to_column(var = "SampleID")

# saliva_bl_pca_df = inner_join(saliva_baseline_pca_df,v1_saliva_df[,1:8] %>% 
#                                      rownames_to_column(var = "SampleID")) %>%
#     # cleaning variable names here
#     mutate(Outcome = ifelse(Outcome == "F", "Failure",
#                                   ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))
# stool_bl_pca_df = inner_join(stool_baseline_pca_df,v1_stool_df[,1:8] %>% 
#                                      rownames_to_column(var = "SampleID")) %>%
#     # cleaning variable names here
#     mutate(Outcome = ifelse(Outcome == "F", "Failure",
#                                   ifelse(Outcome == "SU", "Sustained Unresponsiveness", Outcome)))

# head(saliva_bl_pca_df)

# %%
# options(repr.plot.width=12, repr.plot.height=7) #changing size
# ggplot() + 
#   geom_point(data = saliva_bl_pca_df, aes(x = PC1, y = PC2, color = Outcome, shape = Outcome),
#              size = 3.5) + 
#   stat_ellipse(data = saliva_bl_pca_df , aes(x = PC1, y = PC2, color = Outcome), type = 'norm') + 
#   geom_text_repel(data = saliva_bl_pca_df, 
#                   aes(x = PC1, y = PC2, color = Outcome, label = SampleID), 
#                   segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.3) + 

#   theme_light() + 
#   theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
#         axis.line = element_line(colour="black"), #making x and y axes black
#         axis.text = element_text(size = 13), #changing size of x axis labels
#         legend.title = element_text(face = 'bold', size = 15), #changes legend title
#         legend.text = element_text(size = 12), #changes legend text
#         legend.position = "bottom", 
#         legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
#         axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
#         strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
#         strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

#   labs(x = 'Dimension 1 (30%)', y = 'Dimension 2 (24.9%)', #changing axis labels 
#        color = "Outcome", shape = "Outcome") + #changing legend title

#   scale_color_lancet()

# %%
options(repr.plot.width=12, repr.plot.height=7) #changing size
fviz_pca_ind(saliva_pca, 
             col.ind = v1_saliva_df$Outcome, # color by Group
             palette = 'lancet',
             # adding 95% confidence ellipses for each group
             addEllipses = TRUE, # Concentration ellipses
             ellipse.type = "confidence",
             repel = TRUE, title = "") +
    theme(axis.line = element_line(colour = "black"), #making x and y axes black
      legend.text = element_text(size = 12),
      legend.position = 'bottom',
      axis.title = element_text(face = "bold", size = rel(1.3))) #changes axis titles
# Out:
# plot without title

# %%
# ggplot() + 
#   geom_point(data = stool_bl_pca_df, aes(x = PC1, y = PC2, color = Outcome, shape = Outcome),
#              size = 3.5) + 
#   stat_ellipse(data = stool_bl_pca_df , aes(x = PC1, y = PC2, color = Outcome), type = 'norm') + 
#   geom_text_repel(data = stool_bl_pca_df, 
#                   aes(x = PC1, y = PC2, color = Outcome, label = SampleID), 
#                   segment.size = 0, size = 5, show.legend = FALSE, nudge_y = 0.3) + 

#   theme_light() + 
#   theme(axis.text.x = element_text(vjust = 0.5), #rotating x labels/ moving x labels slightly to the left
#         axis.line = element_line(colour="black"), #making x and y axes black
#         axis.text = element_text(size = 13), #changing size of x axis labels
#         legend.title = element_text(face = 'bold', size = 15), #changes legend title
#         legend.text = element_text(size = 12), #changes legend text
#         legend.position = "bottom", 
#         legend.background = element_rect(colour = 'black', fill = 'white', linetype = 'solid'),
#         axis.title = element_text(face = "bold", size = rel(1.7)), #changes axis titles
#         strip.text.x = element_text(size = 18, face = "bold"), #changes size of facet x axis 
#         strip.text.y = element_text(size = 18, face = "bold")) + #changes size of facet y axis 

#   labs(x = 'Dimension 1 (28%)', y = 'Dimension 2 (20%)', #changing axis labels 
#        color = "Outcome", shape = "Outcome") + #changing legend title

#   scale_color_lancet()

# %%
fviz_pca_ind(stool_pca, 
             col.ind = v1_stool_df$Outcome, # color by Group
             palette = 'lancet',
             # #adding 95% confidence ellipses for each group
             addEllipses = TRUE, # Concentration ellipses
             ellipse.type = "confidence",
             repel = TRUE, title = "") +
 theme(axis.line = element_line(colour = "black"), #making x and y axes black
      legend.text = element_text(size = 12),
      legend.position = 'bottom',
      axis.title = element_text(face = "bold", size = rel(1.3))) #changes axis titles
# Out:
# plot without title

# %%
# calling fn
subject_outliers_saliva = outlier_detection(saliva_pca)
subject_outliers_stool = outlier_detection(stool_pca)  
subject_outliers_saliva
subject_outliers_stool
# Out:
# character(0)
# character(0)

# %% [markdown]
# ## Comparing bacteria abundances based on IgE levels before treatment

# %%
`%notin%` <- Negate(`%in%`)

v2_saliva_df = combined_saliva_df %>%
    # only keep participants' baseline samples 
    filter(Time_Point == 'Pre', Sample_ID != 'Pre_1') %>%
    # making the row names the sample ids
    column_to_rownames(var = 'Sample_ID')

v2_stool_df = combined_stool_df %>%
     filter(Time_Point == 'Pre', Sample_ID != 'Pre_14') %>%
    column_to_rownames(var = 'Sample_ID')

head(v2_saliva_df)
# Out:
#       Original_Sample_ID Subject_No Time_Point Treatment
# Pre_2 FS02baseline       2          Pre        A
# Pre_3 FS04baseline       3          Pre        P
# Pre_4 FS05baseline       4          Pre        A
# Pre_5 FS06baseline       5          Pre        P
# Pre_6 FS07baseline       6          Pre        A
# Pre_8 FS09baseline       8          Pre        P
#       Outcome                    Age      IgE    IgE_Binarized
# Pre_2 Failure                    1.873973  14.20 Low
# Pre_3 Failure                    3.715068  67.40 High
# Pre_4 Failure                    3.991781   9.59 Low
# Pre_5 Failure                    2.356164 106.00 High
# Pre_6 Sustained Unresponsiveness 1.419178   1.32 Low
# Pre_8 Failure                    1.112329  19.10 High
#       k__Bacteria.__.__.__.__.__.__
# Pre_2  0
# Pre_3  4
# Pre_4 24
# Pre_5 82
# Pre_6  7
# Pre_8 53
#       k__Bacteria.p__Absconditabacteria_.SR1..c__Absconditabacteria_.SR1._.C.1..o__Absconditabacteria_.SR1._.O.1..f__Absconditabacteria_.SR1._.F.1..g__Absconditabacteria_.SR1._.G.1..s__bacterium_HMT_874
# Pre_2 16
# Pre_3  0
# Pre_4  0
# Pre_5 11
# Pre_6  0
# Pre_8  0
#       ⋯
# Pre_2 ⋯
# Pre_3 ⋯
# Pre_4 ⋯
# Pre_5 ⋯
# Pre_6 ⋯
# Pre_8 ⋯
#       k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.__.__
# Pre_2 0
# Pre_3 0
# Pre_4 0
# Pre_5 0
# Pre_6 0
# Pre_8 0
#       k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.__
# Pre_2 0
# Pre_3 0
# Pre_4 0
# Pre_5 0
# Pre_6 0
# Pre_8 0
#       k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Aggregatibacter.s__aphrophilus
# Pre_2 46
# Pre_3  0
# Pre_4  0
# Pre_5 50
# Pre_6  0
# Pre_8  0
#       k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.__
# Pre_2  371
# Pre_3    0
# Pre_4  110
# Pre_5  513
# Pre_6 2315
# Pre_8    0
#       k__Bacteria.p__Proteobacteria.c__Gammaproteobacteria.o__Pasteurellales.f__Pasteurellaceae.g__Haemophilus.s__parainfluenzae
# Pre_2 3359
# Pre_3   43
# Pre_4 1225
# Pre_5 2922
# Pre_6 1978
# Pre_8  128
#       k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..__
# Pre_2   0
# Pre_3 414
# Pre_4  40
# Pre_5   0
# Pre_6   0
# Pre_8   0
#       k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_347
# Pre_2  0
# Pre_3 47
# Pre_4  4
# Pre_5  0
# Pre_6 16
# Pre_8  0
#       k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.1..s__bacterium_HMT_352
# Pre_2   0
# Pre_3   0
# Pre_4 403
# Pre_5   0
# Pre_6   0
# Pre_8   2
#       k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.3..s__bacterium_HMT_351
# Pre_2  0
# Pre_3  2
# Pre_4 35
# Pre_5  0
# Pre_6  5
# Pre_8 16
#       k__Bacteria.p__Saccharibacteria_.TM7..c__Saccharibacteria_.TM7._.C.1..o__Saccharibacteria_.TM7._.O.1..f__Saccharibacteria_.TM7._.F.1..g__Saccharibacteria_.TM7._.G.6..s__bacterium_HMT_870
# Pre_2  112
# Pre_3 1050
# Pre_4  167
# Pre_5    0
# Pre_6   28
# Pre_8   10

# %%
# setting seed for reproducibility
set.seed(12)

pca_saliva_df = v2_saliva_df[,9:ncol(v2_saliva_df)]
pca_stool_df = v2_stool_df[,c(10:ncol(v2_stool_df))]

# running pca 
saliva_pca = prcomp(pca_saliva_df)#, center = TRUE, scale = TRUE)
stool_pca = prcomp(pca_stool_df)#, center = TRUE, scale = TRUE)

# looking at a scree plot to see how much of the variance was captured in the first 2 eigenvectors
options(repr.plot.width = 10, repr.plot.height = 5) #changing size
fviz_eig(saliva_pca, addlabels = TRUE)
fviz_eig(stool_pca, addlabels = TRUE)
# Out:
# plot without title
# plot without title

# %%
# calling fn
subject_outliers_saliva = outlier_detection(saliva_pca)
subject_outliers_stool = outlier_detection(stool_pca)  
subject_outliers_saliva
subject_outliers_stool
# Out:
# character(0)
# character(0)

# %%
options(repr.plot.width=12, repr.plot.height=7) #changing size
fviz_pca_ind(saliva_pca, 
             col.ind = v2_saliva_df$IgE_Binarized, # color by Group
             palette = 'futurama',
             # adding 95% confidence ellipses for each group
             addEllipses = TRUE, # Concentration ellipses
             ellipse.type = "confidence",
             repel = TRUE, title = "") +
    theme(axis.line = element_line(colour = "black"), #making x and y axes black
      legend.text = element_text(size = 12),
      legend.position = 'bottom',
      axis.title = element_text(face = "bold", size = rel(1.3))) #changes axis titles
# Out:
# plot without title

# %%
fviz_pca_ind(stool_pca, 
             col.ind = v2_stool_df$IgE_Binarized, # color by Group
             palette = 'futurama',
             # adding 95% confidence ellipses for each group
             addEllipses = TRUE, # Concentration ellipses
             ellipse.type = "confidence",
             repel = TRUE, title = "") +
    theme(axis.line = element_line(colour = "black"), #making x and y axes black
      legend.text = element_text(size = 12),
      legend.position = 'bottom',
      axis.title = element_text(face = "bold", size = rel(1.3))) #changes axis titles
# Out:
# plot without title
